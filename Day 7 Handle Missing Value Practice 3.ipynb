# %%
import numpy as np 
import pandas as pd

# %%
data = {
    'Name':['Tom','James','Ricky','Messi','Ronaldo',np.nan,'Jack'],
    'Age':[25,26,np.nan,23,np.nan,29,23],
    'Rating':[4.23,3.24,3.98,np.nan,4.6,np.nan,4.32]
}

df = pd.DataFrame(data)
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5      NaN  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df['Age'].dtype
# Out:
# dtype('float64')

# %% [markdown]
#     isnull() and isna() both are same it will give boolean as "True"
#     whenever there is a null value or missing value or empty value

# %%
df['Age'].isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# Name: Age, dtype: bool

# %%
df.Age.isin(23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 df.Age.isin(23)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5141, in Series.isin(self, values)
#    5068 def isin(self, values) -> Series:
#    5069     """
#    5070     Whether elements in Series are contained in `values`.
#    5071
#    (...)
#    5139     dtype: bool
#    5140     """
# -> 5141     result = algorithms.isin(self._values, values)
#    5142     return self._constructor(result, index=self.index).__finalize__(
#    5143         self, method="isin"
#    5144     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\algorithms.py:468, in isin(comps, values)
#     463     raise TypeError(
#     464         "only list-like objects are allowed to be passed "
#     465         f"to isin(), you passed a [{type(comps).__name__}]"
#     466     )
#     467 if not is_list_like(values):
# --> 468     raise TypeError(
#     469         "only list-like objects are allowed to be passed "
#     470         f"to isin(), you passed a [{type(values).__name__}]"
#     471     )
#     473 if not isinstance(values, (ABCIndex, ABCSeries, ABCExtensionArray, np.ndarray)):
#     474     values = _ensure_arraylike(list(values))
#
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [int]

# %%
df.isnull()
# Out:
#     Name    Age  Rating
# 0  False  False   False
# 1  False  False   False
# 2  False   True   False
# 3  False  False    True
# 4  False   True   False
# 5   True  False    True
# 6  False  False   False

# %%
df.isna()
# Out:
#     Name    Age  Rating
# 0  False  False   False
# 1  False  False   False
# 2  False   True   False
# 3  False  False    True
# 4  False   True   False
# 5   True  False    True
# 6  False  False   False

# %%
# to get the sum of the null values
df.isna().sum()
# Out:
# Name      1
# Age       2
# Rating    2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name      1
# Age       2
# Rating    2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# 2

# %%
df.Age.isna().sum()
# Out:
# 2

# %%
df.isnull().sum().head()
# Out:
# Name      1
# Age       2
# Rating    2
# dtype: int64

# %%
df.isnull().sum().head(2)
# Out:
# Name    1
# Age     2
# dtype: int64

# %%
df.isna()
# Out:
#     Name    Age  Rating
# 0  False  False   False
# 1  False  False   False
# 2  False   True   False
# 3  False  False    True
# 4  False   True   False
# 5   True  False    True
# 6  False  False   False

# %%
df.isna().sum()
# Out:
# Name      1
# Age       2
# Rating    2
# dtype: int64

# %%
df.notna()
# Out:
#     Name    Age  Rating
# 0   True   True    True
# 1   True   True    True
# 2   True  False    True
# 3   True   True   False
# 4   True  False    True
# 5  False   True   False
# 6   True   True    True

# %%
a = df.notna()

# %%
a[a]
# Out:
#    Name   Age Rating
# 0  True  True   True
# 1  True  True   True
# 2  True   NaN   True
# 3  True  True    NaN
# 4  True   NaN   True
# 5   NaN  True    NaN
# 6  True  True   True

# %%
df[a]
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5      NaN  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.notnull()
# Out:
#     Name    Age  Rating
# 0   True   True    True
# 1   True   True    True
# 2   True  False    True
# 3   True   True   False
# 4   True  False    True
# 5  False   True   False
# 6   True   True    True

# %%
df.notnull().sum()
# Out:
# Name      6
# Age       5
# Rating    5
# dtype: int64

# %%
df.notna()
# Out:
#     Name    Age  Rating
# 0   True   True    True
# 1   True   True    True
# 2   True  False    True
# 3   True   True   False
# 4   True  False    True
# 5  False   True   False
# 6   True   True    True

# %%
df.notna().sum()
# Out:
# Name      6
# Age       5
# Rating    5
# dtype: int64

# %%
df.notnull().sum().min()
# Out:
# 5

# %%
df.notnull().sum().max()
# Out:
# 6

# %%
# it will return the sum of the existing value 
df.notnull().sum()
# Out:
# Name      6
# Age       5
# Rating    5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     5 non-null      float64
#  2   Rating  5 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 296.0+ bytes

# %% [markdown]
# # Cleaning and Filling Missing Data

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5      NaN  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df['Name'].fillna('Neymar')
# Out:
# 0        Tom
# 1      James
# 2      Ricky
# 3      Messi
# 4    Ronaldo
# 5     Neymar
# 6       Jack
# Name: Name, dtype: object

# %%
# To make it permenant inplace  = True
df['Name'].fillna('Neymar',inplace=True)

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %% [markdown]
# ### Handling Missing Values

# %%
# It will by default delete the rows which consist "Nan" Values
df.dropna()
# Out:
#     Name   Age  Rating
# 0    Tom  25.0    4.23
# 1  James  26.0    3.24
# 6   Jack  23.0    4.32

# %%
df.dropna(axis=0)
# Out:
#     Name   Age  Rating
# 0    Tom  25.0    4.23
# 1  James  26.0    3.24
# 6   Jack  23.0    4.32

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# to the delete the Rows which consist 'nan' value permanently
df.dropna(inplace=True)

# %%
df
# Out:
#     Name   Age  Rating
# 0    Tom  25.0    4.23
# 1  James  26.0    3.24
# 6   Jack  23.0    4.32

# %%
# see the Rows got delete permanently 
df
# Out:
#     Name   Age  Rating
# 0    Tom  25.0    4.23
# 1  James  26.0    3.24
# 6   Jack  23.0    4.32

# %%
data = {
    'Name':['Tom','James','Ricky','Messi','Ronaldo',np.nan,'Jack'],
    'Age':[25,26,np.nan,23,np.nan,29,23],
    'Rating':[4.23,3.24,3.98,np.nan,4.6,np.nan,4.32]
}

df = pd.DataFrame(data)
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5      NaN  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df['Name'].fillna('Neymar',inplace=True)

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# lets drop the columns which consist of "nan" Values
df.dropna(axis=1)
# Out:
#       Name
# 0      Tom
# 1    James
# 2    Ricky
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
# to delte the columns permanently then same inplace = True
df.dropna(axis=1,inplace=True)

# %%
df
# see the columns got deleted permanently
# Out:
#       Name
# 0      Tom
# 1    James
# 2    Ricky
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
df
# Out:
#       Name
# 0      Tom
# 1    James
# 2    Ricky
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
# dtypes: object(1)
# memory usage: 184.0+ bytes

# %%
data = {
    'Name':['Tom','James','Ricky','Messi','Ronaldo',np.nan,'Jack'],
    'Age':[25,26,np.nan,23,np.nan,29,23],
    'Rating':[4.23,3.24,3.98,np.nan,4.6,np.nan,4.32]
}

df = pd.DataFrame(data)
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5      NaN  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df['Name'].fillna('Neymar',inplace=True)

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.dropna()
# Out:
#     Name   Age  Rating
# 0    Tom  25.0    4.23
# 1  James  26.0    3.24
# 6   Jack  23.0    4.32

# %%
# After dropping the "Nan" rows we can also calculate remaning "Nan" values
df.dropna().isnull().sum()
# Out:
# Name      0
# Age       0
# Rating    0
# dtype: int64

# %%
df.dropna().notna().sum()
# Out:
# Name      3
# Age       3
# Rating    3
# dtype: int64

# %%
# checking fo9r the "Age" for Non-Null Values
df.Age.notnull().sum()
# Out:
# 5

# %% [markdown]
# ### Replacing The Missing Value

# %%
# we are going to replace all the 'nan' with "Blank"
df.replace(np.nan,'Blank')
# Out:
#       Name    Age Rating
# 0      Tom   25.0   4.23
# 1    James   26.0   3.24
# 2    Ricky  Blank   3.98
# 3    Messi   23.0  Blank
# 4  Ronaldo  Blank    4.6
# 5   Neymar   29.0  Blank
# 6     Jack   23.0   4.32

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# to replace it with permanently
df.replace(np.nan,'Blank',inplace=True)

# %%
df
# Out:
#       Name    Age Rating
# 0      Tom   25.0   4.23
# 1    James   26.0   3.24
# 2    Ricky  Blank   3.98
# 3    Messi   23.0  Blank
# 4  Ronaldo  Blank    4.6
# 5   Neymar   29.0  Blank
# 6     Jack   23.0   4.32

# %%
# if you want to replace the "Blank" with "nan"
df.replace("Blank",np.nan)
# to change it permanently use inplace=True
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df
# Out:
#       Name    Age Rating
# 0      Tom   25.0   4.23
# 1    James   26.0   3.24
# 2    Ricky  Blank   3.98
# 3    Messi   23.0  Blank
# 4  Ronaldo  Blank    4.6
# 5   Neymar   29.0  Blank
# 6     Jack   23.0   4.32

# %%
df['Age'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [75], line 1
# ----> 1 df['Age'].sum()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:11074, in NDFrame._add_numeric_operations.<locals>.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11054 @doc(
#   11055     _num_doc,
#   11056     desc="Return the sum of the values over the requested axis.\n\n"
#    (...)
#   11072     **kwargs,
#   11073 ):
# > 11074     return NDFrame.sum(
#   11075         self, axis, skipna, level, numeric_only, min_count, **kwargs
#   11076     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:10794, in NDFrame.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10785 def sum(
#   10786     self,
#   10787     axis: Axis | None = None,
#    (...)
#   10792     **kwargs,
#   10793 ):
# > 10794     return self._min_count_stat_function(
#   10795         "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10796     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:10776, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10760     warnings.warn(
#   10761         "Using the level keyword in DataFrame and Series aggregations is "
#   10762         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   10765         stacklevel=find_stack_level(),
#   10766     )
#   10767     return self._agg_by_level(
#   10768         name,
#   10769         axis=axis,
#    (...)
#   10773         numeric_only=numeric_only,
#   10774     )
# > 10776 return self._reduce(
#   10777     func,
#   10778     name=name,
#   10779     axis=axis,
#   10780     skipna=skipna,
#   10781     numeric_only=numeric_only,
#   10782     min_count=min_count,
#   10783 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4471, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4467     raise NotImplementedError(
#    4468         f"Series.{name} does not implement {kwd_name}."
#    4469     )
#    4470 with np.errstate(all="ignore"):
# -> 4471     return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:410, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     407 if datetimelike and mask is None:
#     408     mask = isna(values)
# --> 410 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412 if datetimelike:
#     413     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:483, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     480         results = [func(x, **kwargs) for x in arrs]
#     481     return np.array(results)
# --> 483 return func(values, axis=axis, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:623, in nansum(values, axis, skipna, min_count, mask)
#     620 elif is_timedelta64_dtype(dtype):
#     621     dtype_sum = np.dtype(np.float64)
# --> 623 the_sum = values.sum(axis, dtype=dtype_sum)
#     624 the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     626 return the_sum
#
# File ~\anaconda3\lib\site-packages\numpy\core\_methods.py:48, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
df.mean()
# Out:
# C:\Users\HRISHIKESH\AppData\Local\Temp\ipykernel_4380\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Series([], dtype: float64)

# %%
df.replace("Blank",np.nan,inplace=True)

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.Age.mean()
# Out:
# 25.2

# %%
# Replace the missing value in the Age column with mean value
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    25.0
# 1    26.0
# 2    25.2
# 3    23.0
# 4    25.2
# 5    29.0
# 6    23.0
# Name: Age, dtype: float64

# %%
df
# As you cann see  the values hasnt changed permanently 
# to do that will use inplace = True
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df['Rating'].mean()
# Out:
# 4.074

# %%
# Replace the missing value in the Rating column with mean value
df['Rating'].fillna(df['Rating'].mean())
# Out:
# 0    4.230
# 1    3.240
# 2    3.980
# 3    4.074
# 4    4.600
# 5    4.074
# 6    4.320
# Name: Rating, dtype: float64

# %% [markdown]
# ### Drop Functions

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# Drop the "Age" column
# whenever you want t o delete a column always mention "axis = 1"
# axis = 0 for Rows
# axis = 1 for Columns
df.drop(['Age'],axis=1)
# Out:
#       Name  Rating
# 0      Tom    4.23
# 1    James    3.24
# 2    Ricky    3.98
# 3    Messi     NaN
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
df.drop(['Age'],axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [93], line 1
# ----> 1 df.drop(['Age'],axis=0)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4809 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4810 def drop(
#    4811     self,
#    (...)
#    4818     errors: str = "raise",
#    4819 ):
#    4820     """
#    4821     Drop specified labels from rows or columns.
#    4822
#    (...)
#    4955             weight  1.0     0.8
#    4956     """
# -> 4957     return super().drop(
#    4958         labels=labels,
#    4959         axis=axis,
#    4960         index=index,
#    4961         columns=columns,
#    4962         level=level,
#    4963         inplace=inplace,
#    4964         errors=errors,
#    4965     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6661, in Index.drop(self, labels, errors)
#    6659 if mask.any():
#    6660     if errors != "ignore":
# -> 6661         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662     indexer = indexer[~mask]
#    6663 return self.delete(indexer)
#
# KeyError: "['Age'] not found in axis"

# %%
df.drop(columns='Age',axis=1)
# Out:
#       Name  Rating
# 0      Tom    4.23
# 1    James    3.24
# 2    Ricky    3.98
# 3    Messi     NaN
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
df.drop(columns=['Age','Rating'],axis=1)
# Out:
#       Name
# 0      Tom
# 1    James
# 2    Ricky
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
df.drop(columns=['Age','Rating','Name'],axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.drop(index=[1,2,3],columns='Age')
# Out:
#       Name  Rating
# 0      Tom    4.23
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
df.drop(index=[0,2],columns = ['Age','Rating'])
# Out:
#       Name
# 1    James
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
# Deleting multiple columns
df.drop(['Age','Rating'],axis=1)
# Out:
#       Name
# 0      Tom
# 1    James
# 2    Ricky
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# Alternate way to solve the above column is:
# for single column 
df.drop(columns='Age')
# Out:
#       Name  Rating
# 0      Tom    4.23
# 1    James    3.24
# 2    Ricky    3.98
# 3    Messi     NaN
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
df.drop(columns='Age',axis=1)
# Out:
#       Name  Rating
# 0      Tom    4.23
# 1    James    3.24
# 2    Ricky    3.98
# 3    Messi     NaN
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
df.drop(columns='Age',axis=0)
# Out:
#       Name  Rating
# 0      Tom    4.23
# 1    James    3.24
# 2    Ricky    3.98
# 3    Messi     NaN
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
df.drop(index=[1,3,5])
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60
# 6     Jack  23.0    4.32

# %%
df.drop(index=[0,2,4,6],axis=0)
# Out:
#      Name   Age  Rating
# 1   James  26.0    3.24
# 3   Messi  23.0     NaN
# 5  Neymar  29.0     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).T
# Out:
#             1      3       5
# Name    James  Messi  Neymar
# Age      26.0   23.0    29.0
# Rating   3.24    NaN     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).sort_index()
# by default Ascending
# Out:
#      Name   Age  Rating
# 1   James  26.0    3.24
# 3   Messi  23.0     NaN
# 5  Neymar  29.0     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).sort_index(ascending=False)
# Now Descending
# Out:
#      Name   Age  Rating
# 5  Neymar  29.0     NaN
# 3   Messi  23.0     NaN
# 1   James  26.0    3.24

# %%
df.drop(index=[0,2,4,6],axis=0).sort_values('Age')
# by default Ascending
# Out:
#      Name   Age  Rating
# 3   Messi  23.0     NaN
# 1   James  26.0    3.24
# 5  Neymar  29.0     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).sort_values('Age',ascending=False)
# Out:
#      Name   Age  Rating
# 5  Neymar  29.0     NaN
# 1   James  26.0    3.24
# 3   Messi  23.0     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).sort_values('Age',ascending=False).loc[:,['Rating','Name']]
# Out:
#    Rating    Name
# 5     NaN  Neymar
# 1    3.24   James
# 3     NaN   Messi

# %%
df.drop(index=[0,2,4,6],axis=0).sort_values('Age',ascending=False).loc[:,['Rating','Age']]
# Out:
#    Rating   Age
# 5     NaN  29.0
# 1    3.24  26.0
# 3     NaN  23.0

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.drop(index=[0,2,4,6],axis=0).sort_values('Age',ascending=False).iloc[:,[0,2]]
# Out:
#      Name  Rating
# 5  Neymar     NaN
# 1   James    3.24
# 3   Messi     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).sort_values('Age',ascending=False).iloc[:,[0,1]]
# Out:
#      Name   Age
# 5  Neymar  29.0
# 1   James  26.0
# 3   Messi  23.0

# %%
# for multiple column is:
df.drop(columns=['Age','Rating'])
# Out:
#       Name
# 0      Tom
# 1    James
# 2    Ricky
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %% [markdown]
# ### lets try to drop the Rows using Indexing

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# here in the list we are passing the index value 
# dont count it as in the form of Rows and Columns 
df.drop([1,2,3])
# to delete it permanently will use inplace = True
# 0th and 2nd index position rows got deleted
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.drop([2,1,0])
# Out:
#       Name   Age  Rating
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.drop([2,0])
# Out:
#       Name   Age  Rating
# 1    James  26.0    3.24
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# now lete delete rows which has index value of 1,3,4,6
df.drop([1,3,4,6])
# As you can see it has deleted the rows which i passed in the list
# Out:
#      Name   Age  Rating
# 0     Tom  25.0    4.23
# 2   Ricky   NaN    3.98
# 5  Neymar  29.0     NaN

# %%
# Alternate way using Index Parameter
df.drop(index=[1,3,5])
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60
# 6     Jack  23.0    4.32

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# It has deleted the whole Column 
df.drop(index=1,columns='Age')
# Out:
#       Name  Rating
# 0      Tom    4.23
# 2    Ricky    3.98
# 3    Messi     NaN
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
df.drop(index=[1,3,5,6],columns='Age')
# Out:
#       Name  Rating
# 0      Tom    4.23
# 2    Ricky    3.98
# 4  Ronaldo    4.60

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.drop(index=[1,3,5,6],columns=['Age','Rating'])
# Out:
#       Name
# 0      Tom
# 2    Ricky
# 4  Ronaldo

# %%
df.drop(index=1)
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# As we can see like query is giving us the Output,
# but it doesnt make any sense it delete the whole columns
df.drop(index=[1,3,4],columns=['Age','Name'])
# Out:
#    Rating
# 0    4.23
# 2    3.98
# 5     NaN
# 6    4.32

# %%
df.drop(columns=['Age','Rating'])
# Out:
#       Name
# 0      Tom
# 1    James
# 2    Ricky
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
# lets sort the values
df.sort_values(by='Age')
# It has Sorted the Age values in the Ascending Order
# Out:
#       Name   Age  Rating
# 3    Messi  23.0     NaN
# 6     Jack  23.0    4.32
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 5   Neymar  29.0     NaN
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60

# %%
df.sort_values(by=['Age','Rating'])['Age']
# Out:
# 6    23.0
# 3    23.0
# 0    25.0
# 1    26.0
# 5    29.0
# 2     NaN
# 4     NaN
# Name: Age, dtype: float64

# %%
df.sort_values(by=['Age','Rating'])[['Age']]
# Out:
#     Age
# 6  23.0
# 3  23.0
# 0  25.0
# 1  26.0
# 5  29.0
# 2   NaN
# 4   NaN

# %%
df.sort_values(by=['Age','Rating'])[['Name','Age']]
# Out:
#       Name   Age
# 6     Jack  23.0
# 3    Messi  23.0
# 0      Tom  25.0
# 1    James  26.0
# 5   Neymar  29.0
# 2    Ricky   NaN
# 4  Ronaldo   NaN

# %%
df.sort_values(by=['Age','Rating']).iloc[:,1]
# Out:
# 6    23.0
# 3    23.0
# 0    25.0
# 1    26.0
# 5    29.0
# 2     NaN
# 4     NaN
# Name: Age, dtype: float64

# %%
df.sort_values(by='Age').iloc[:,[1]]
# Out:
#     Age
# 3  23.0
# 6  23.0
# 0  25.0
# 1  26.0
# 5  29.0
# 2   NaN
# 4   NaN

# %%
df.sort_values(by='Age').iloc[:,[1,2]]
# Out:
#     Age  Rating
# 3  23.0     NaN
# 6  23.0    4.32
# 0  25.0    4.23
# 1  26.0    3.24
# 5  29.0     NaN
# 2   NaN    3.98
# 4   NaN    4.60

# %%
df.sort_values(by='Age').iloc[:,[1,2,0]]
# Out:
#     Age  Rating     Name
# 3  23.0     NaN    Messi
# 6  23.0    4.32     Jack
# 0  25.0    4.23      Tom
# 1  26.0    3.24    James
# 5  29.0     NaN   Neymar
# 2   NaN    3.98    Ricky
# 4   NaN    4.60  Ronaldo

# %%
df.sort_values(by=['Age','Rating']).loc[:,['Age']]
# Out:
#     Age
# 6  23.0
# 3  23.0
# 0  25.0
# 1  26.0
# 5  29.0
# 2   NaN
# 4   NaN

# %%
df.sort_values(by=['Age','Rating']).loc[:,['Age','Rating']]
# Out:
#     Age  Rating
# 6  23.0    4.32
# 3  23.0     NaN
# 0  25.0    4.23
# 1  26.0    3.24
# 5  29.0     NaN
# 2   NaN    3.98
# 4   NaN    4.60

# %%
df.sort_values(by=['Age','Rating'])[['Name','Age']]
# Out:
#       Name   Age
# 6     Jack  23.0
# 3    Messi  23.0
# 0      Tom  25.0
# 1    James  26.0
# 5   Neymar  29.0
# 2    Ricky   NaN
# 4  Ronaldo   NaN

# %%
df.sort_values(by=['Age','Rating'],ascending=False)[['Name','Age']]
# Out:
#       Name   Age
# 5   Neymar  29.0
# 1    James  26.0
# 0      Tom  25.0
# 6     Jack  23.0
# 3    Messi  23.0
# 4  Ronaldo   NaN
# 2    Ricky   NaN

# %%
# Alternate way
df.Age.sort_values()
# Out:
# 3    23.0
# 6    23.0
# 0    25.0
# 1    26.0
# 5    29.0
# 2     NaN
# 4     NaN
# Name: Age, dtype: float64

# %%
df['Age'].sort_values()[['Name']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [160], line 1
# ----> 1 df['Age'].sort_values()[['Name']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:984, in Series.__getitem__(self, key)
#     981     key = np.asarray(key, dtype=bool)
#     982     return self._get_values(key)
# --> 984 return self._get_with(key)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1024, in Series._get_with(self, key)
#    1021         return self.iloc[key]
#    1023 # handle the dup indexing case GH#4246
# -> 1024 return self.loc[key]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1194, in _LocIndexer._getitem_axis(self, key, axis)
#    1191     if hasattr(key, "ndim") and key.ndim > 1:
#    1192         raise ValueError("Cannot index with multidimensional key")
# -> 1194     return self._getitem_iterable(key, axis=axis)
#    1196 # nested tuple slicing
#    1197 if is_nested_tuple(key, labels):
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1132, in _LocIndexer._getitem_iterable(self, key, axis)
#    1129 self._validate_key(key, axis)
#    1131 # A collection of keys
# -> 1132 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1133 return self.obj._reindex_with_indexers(
#    1134     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1135 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1330, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1327 ax = self.obj._get_axis(axis)
#    1328 axis_name = self.obj._get_axis_name(axis)
# -> 1330 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1332 return keyarr, indexer
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5856, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5854     if use_interval_msg:
#    5855         key = list(key)
# -> 5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Name'], dtype='object')] are in the [index]"

# %%
df.sort_values('Age')
# Out:
#       Name   Age  Rating
# 3    Messi  23.0     NaN
# 6     Jack  23.0    4.32
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 5   Neymar  29.0     NaN
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60

# %%
df.sort_values('Age')[['Age']]
# Out:
#     Age
# 3  23.0
# 6  23.0
# 0  25.0
# 1  26.0
# 5  29.0
# 2   NaN
# 4   NaN

# %%
df['Age'].sort_values()
# Out:
# 3    23.0
# 6    23.0
# 0    25.0
# 1    26.0
# 5    29.0
# 2     NaN
# 4     NaN
# Name: Age, dtype: float64

# %%
df.sort_values('Age')
# Out:
#       Name   Age  Rating
# 3    Messi  23.0     NaN
# 6     Jack  23.0    4.32
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 5   Neymar  29.0     NaN
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60

# %%
df['Age'].sort_values(ascending=False)
# Out:
# 5    29.0
# 1    26.0
# 0    25.0
# 3    23.0
# 6    23.0
# 2     NaN
# 4     NaN
# Name: Age, dtype: float64

# %%
df.sort_values(by=["Age"],ascending=False)
# Out:
#       Name   Age  Rating
# 5   Neymar  29.0     NaN
# 1    James  26.0    3.24
# 0      Tom  25.0    4.23
# 3    Messi  23.0     NaN
# 6     Jack  23.0    4.32
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60

# %%
df.sort_values(by=["Age"],ascending=False)['Age']
# Out:
# 5    29.0
# 1    26.0
# 0    25.0
# 3    23.0
# 6    23.0
# 2     NaN
# 4     NaN
# Name: Age, dtype: float64

# %%
df.sort_values(by=["Age"],ascending=False)[['Age']]
# Out:
#     Age
# 5  29.0
# 1  26.0
# 0  25.0
# 3  23.0
# 6  23.0
# 2   NaN
# 4   NaN

# %%
df.sort_values(by=["Age"],ascending=False)[['Age','Name']]
# Out:
#     Age     Name
# 5  29.0   Neymar
# 1  26.0    James
# 0  25.0      Tom
# 3  23.0    Messi
# 6  23.0     Jack
# 2   NaN    Ricky
# 4   NaN  Ronaldo

# %%
df.sort_values(by=["Age"],ascending=False).loc[:,['Age']]
# Out:
#     Age
# 5  29.0
# 1  26.0
# 0  25.0
# 3  23.0
# 6  23.0
# 2   NaN
# 4   NaN

# %%
df.sort_values(by=["Age"],ascending=False).loc[:,['Age','Name']]
# Out:
#     Age     Name
# 5  29.0   Neymar
# 1  26.0    James
# 0  25.0      Tom
# 3  23.0    Messi
# 6  23.0     Jack
# 2   NaN    Ricky
# 4   NaN  Ronaldo

# %%
df.sort_values(by=['Age','Rating'])
# bydefault it will give the first preference to the Age column
# Out:
#       Name   Age  Rating
# 6     Jack  23.0    4.32
# 3    Messi  23.0     NaN
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 5   Neymar  29.0     NaN
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60

# %%
df.sort_values(by=['Age','Rating']).iloc[:,::-1]
# Out:
#    Rating   Age     Name
# 6    4.32  23.0     Jack
# 3     NaN  23.0    Messi
# 0    4.23  25.0      Tom
# 1    3.24  26.0    James
# 5     NaN  29.0   Neymar
# 2    3.98   NaN    Ricky
# 4    4.60   NaN  Ronaldo

# %%
df.sort_values(by=['Rating','Age'],ascending=False)
# Out:
#       Name   Age  Rating
# 4  Ronaldo   NaN    4.60
# 6     Jack  23.0    4.32
# 0      Tom  25.0    4.23
# 2    Ricky   NaN    3.98
# 1    James  26.0    3.24
# 5   Neymar  29.0     NaN
# 3    Messi  23.0     NaN

# %%
df.sort_index()
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.sort_index(ascending=False)
# Out:
#       Name   Age  Rating
# 6     Jack  23.0    4.32
# 5   Neymar  29.0     NaN
# 4  Ronaldo   NaN    4.60
# 3    Messi  23.0     NaN
# 2    Ricky   NaN    3.98
# 1    James  26.0    3.24
# 0      Tom  25.0    4.23

# %%
df.sort_index(axis=1)
# it will sort the column name Ascending wise
# Out:
#     Age     Name  Rating
# 0  25.0      Tom    4.23
# 1  26.0    James    3.24
# 2   NaN    Ricky    3.98
# 3  23.0    Messi     NaN
# 4   NaN  Ronaldo    4.60
# 5  29.0   Neymar     NaN
# 6  23.0     Jack    4.32

# %%
df.sort_index(axis=1,ascending=False)
# it will sort the column name descending wise
# Out:
#    Rating     Name   Age
# 0    4.23      Tom  25.0
# 1    3.24    James  26.0
# 2    3.98    Ricky   NaN
# 3     NaN    Messi  23.0
# 4    4.60  Ronaldo   NaN
# 5     NaN   Neymar  29.0
# 6    4.32     Jack  23.0

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#       Name   Age  Rating
# 6     Jack  23.0    4.32
# 5   Neymar  29.0     NaN
# 4  Ronaldo   NaN    4.60
# 3    Messi  23.0     NaN
# 2    Ricky   NaN    3.98
# 1    James  26.0    3.24
# 0      Tom  25.0    4.23

# %%
df.sort_index(axis=1).iloc[:,::-1]
# Out:
#    Rating     Name   Age
# 0    4.23      Tom  25.0
# 1    3.24    James  26.0
# 2    3.98    Ricky   NaN
# 3     NaN    Messi  23.0
# 4    4.60  Ronaldo   NaN
# 5     NaN   Neymar  29.0
# 6    4.32     Jack  23.0

# %%
# let see how clipboard() works 
# let a copy a tabular form dataset 
# after copying to do below following task
df = pd.read_clipboard()
df
# Out:
#     Year                 Winner                    Runner Up         Venue  \
# 0   2022         Gujarat Titans             Rajasthan Royals     Ahmedabad
# 1   2021    Chennai Super Kings        Kolkata Knight Riders         Dubai
# 2   2020         Mumbai Indians               Delhi Capitals         Dubai
# 3   2019         Mumbai Indians          Chennai Super Kings     Hyderabad
# 4   2018    Chennai Super Kings          Sunrisers Hyderabad        Mumbai
# 5   2017         Mumbai Indians      Rising Pune Supergiants     Hyderabad
# 6   2016    Sunrisers Hyderabad  Royal Challengers Bangalore     Bangalore
# 7   2015         Mumbai Indians          Chennai Super Kings       Kolkata
# 8   2014  Kolkata Knight Riders              Kings XI Punjab     Bangalore
# 9   2013         Mumbai Indians          Chennai Super Kings       Kolkata
# 10  2012  Kolkata Knight Riders          Chennai Super Kings       Chennai
# 11  2011    Chennai Super Kings  Royal Challengers Bangalore       Chennai
# 12  2010    Chennai Super Kings               Mumbai Indians        Mumbai
# 13  2009        Deccan Chargers  Royal Challengers Bangalore  Johhanesburg
# 14  2008       Rajasthan Royals          Chennai Super Kings        Mumbai
#
#     Number of teams Player of the Match
# 0                10                  --
# 1                 8      Faf du Plessis
# 2                 8         Trent Boult
# 3                 8      Jasprit Bumrah
# 4                 8        Shane Watson
# 5                 8       Krunal Pandya
# 6                 8         Ben Cutting
# 7                 8        Rohit Sharma
# 8                 8       Manish Pandey
# 9                 9      Kieron Pollard
# 10                9     Manvinder Bisla
# 11               10        Murali Vijay
# 12                8        Suresh Raina
# 13                8         Anil Kumble
# 14                8        Yusuf Pathan

# %%
df['Player of the Match'] = df['Player of the Match'].str.replace('--','xyz')

# %%
df
# Out:
#     Year                 Winner                    Runner Up         Venue  \
# 0   2022         Gujarat Titans             Rajasthan Royals     Ahmedabad
# 1   2021    Chennai Super Kings        Kolkata Knight Riders         Dubai
# 2   2020         Mumbai Indians               Delhi Capitals         Dubai
# 3   2019         Mumbai Indians          Chennai Super Kings     Hyderabad
# 4   2018    Chennai Super Kings          Sunrisers Hyderabad        Mumbai
# 5   2017         Mumbai Indians      Rising Pune Supergiants     Hyderabad
# 6   2016    Sunrisers Hyderabad  Royal Challengers Bangalore     Bangalore
# 7   2015         Mumbai Indians          Chennai Super Kings       Kolkata
# 8   2014  Kolkata Knight Riders              Kings XI Punjab     Bangalore
# 9   2013         Mumbai Indians          Chennai Super Kings       Kolkata
# 10  2012  Kolkata Knight Riders          Chennai Super Kings       Chennai
# 11  2011    Chennai Super Kings  Royal Challengers Bangalore       Chennai
# 12  2010    Chennai Super Kings               Mumbai Indians        Mumbai
# 13  2009        Deccan Chargers  Royal Challengers Bangalore  Johhanesburg
# 14  2008       Rajasthan Royals          Chennai Super Kings        Mumbai
#
#     Number of teams Player of the Match
# 0                10                 xyz
# 1                 8      Faf du Plessis
# 2                 8         Trent Boult
# 3                 8      Jasprit Bumrah
# 4                 8        Shane Watson
# 5                 8       Krunal Pandya
# 6                 8         Ben Cutting
# 7                 8        Rohit Sharma
# 8                 8       Manish Pandey
# 9                 9      Kieron Pollard
# 10                9     Manvinder Bisla
# 11               10        Murali Vijay
# 12                8        Suresh Raina
# 13                8         Anil Kumble
# 14                8        Yusuf Pathan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 15 non-null     int64
#  1   Winner               15 non-null     object
#  2   Runner Up            15 non-null     object
#  3   Venue                15 non-null     object
#  4   Number of teams      15 non-null     int64
#  5   Player of the Match  15 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 840.0+ bytes

# %%
df.isnull().sum()
# Out:
# Year                   0
# Winner                 0
# Runner Up              0
# Venue                  0
# Number of teams        0
# Player of the Match    0
# dtype: int64
