# %%
import numpy as np 
import pandas as pd

# %%
data = {
    'Name':['Tom','James','Ricky','Messi','Ronaldo',np.nan,'Jack'],
    'Age':[25,26,np.nan,23,np.nan,29,23],
    'Rating':[4.23,3.24,3.98,np.nan,4.6,np.nan,4.32]
}

df = pd.DataFrame(data)
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5      NaN  29.0     NaN
# 6     Jack  23.0    4.32

# %% [markdown]
#     isnull() and isna() both are same it will give boolean as "True"
#     whenever there is a null value or missing value or empty value

# %%
df.isnull()
# Out:
#     Name    Age  Rating
# 0  False  False   False
# 1  False  False   False
# 2  False   True   False
# 3  False  False    True
# 4  False   True   False
# 5   True  False    True
# 6  False  False   False

# %%
df.isna()
# Out:
#     Name    Age  Rating
# 0  False  False   False
# 1  False  False   False
# 2  False   True   False
# 3  False  False    True
# 4  False   True   False
# 5   True  False    True
# 6  False  False   False

# %%
# to get the sum of the null values
df.isnull().sum()
# Out:
# Name      1
# Age       2
# Rating    2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# 2

# %%
df.Age.isnull().sum()
# Out:
# 2

# %%
df.isnull().sum().head()
# Out:
# Name      1
# Age       2
# Rating    2
# dtype: int64

# %%
df.isnull().sum().head(2)
# Out:
# Name    1
# Age     2
# dtype: int64

# %%
df.isnull().sum().tail()
# Out:
# Name      1
# Age       2
# Rating    2
# dtype: int64

# %%
df.isna()
# Out:
#     Name    Age  Rating
# 0  False  False   False
# 1  False  False   False
# 2  False   True   False
# 3  False  False    True
# 4  False   True   False
# 5   True  False    True
# 6  False  False   False

# %%
df.isna().sum()
# Out:
# Name      1
# Age       2
# Rating    2
# dtype: int64

# %%
df.notna()
# Out:
#     Name    Age  Rating
# 0   True   True    True
# 1   True   True    True
# 2   True  False    True
# 3   True   True   False
# 4   True  False    True
# 5  False   True   False
# 6   True   True    True

# %%
df.notnull()
# Out:
#     Name    Age  Rating
# 0   True   True    True
# 1   True   True    True
# 2   True  False    True
# 3   True   True   False
# 4   True  False    True
# 5  False   True   False
# 6   True   True    True

# %%
df.notna().sum()
# Out:
# Name      6
# Age       5
# Rating    5
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Name      6
# Age       5
# Rating    5
# dtype: int64

# %%
df.notnull().sum().min()
# Out:
# 5

# %%
df.notnull().sum().max()
# Out:
# 6

# %%
# it will return the sum of the existing value 
df.notnull().sum()
# Out:
# Name      6
# Age       5
# Rating    5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     5 non-null      float64
#  2   Rating  5 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 296.0+ bytes

# %% [markdown]
# ### Cleaning and Filling Missing Data

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5      NaN  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df['Name'].fillna('Neymar')
# Out:
# 0        Tom
# 1      James
# 2      Ricky
# 3      Messi
# 4    Ronaldo
# 5     Neymar
# 6       Jack
# Name: Name, dtype: object

# %%
# To make it permenant inplace  = True
df.Name.fillna('Neymar',inplace=True)

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %% [markdown]
# ## Handle the Missing Value

# %%
# It will by default delete the rows which consist "Nan" Values
df.dropna()
# Out:
#     Name   Age  Rating
# 0    Tom  25.0    4.23
# 1  James  26.0    3.24
# 6   Jack  23.0    4.32

# %%
df.dropna(axis=0)
# Out:
#     Name   Age  Rating
# 0    Tom  25.0    4.23
# 1  James  26.0    3.24
# 6   Jack  23.0    4.32

# %%
df.dropna(axis=1)
# Out:
#       Name
# 0      Tom
# 1    James
# 2    Ricky
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
df.dropna()

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.dropna(axis=0)
# Out:
#     Name   Age  Rating
# 0    Tom  25.0    4.23
# 1  James  26.0    3.24
# 6   Jack  23.0    4.32

# %%
# After dropping the "Nan" rows we can also calculate remaning "Nan" values
df.dropna().isnull().sum()
# Out:
# Name      0
# Age       0
# Rating    0
# dtype: int64

# %%
df.dropna().notnull().sum()
# Out:
# Name      3
# Age       3
# Rating    3
# dtype: int64

# %%
df.Age.notnull().sum()
# Out:
# 5

# %% [markdown]
# ## Replacing the Missing Value

# %%
df.replace(np.nan,'Blank')
# Out:
#       Name    Age Rating
# 0      Tom   25.0   4.23
# 1    James   26.0   3.24
# 2    Ricky  Blank   3.98
# 3    Messi   23.0  Blank
# 4  Ronaldo  Blank    4.6
# 5   Neymar   29.0  Blank
# 6     Jack   23.0   4.32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     5 non-null      float64
#  2   Rating  5 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 296.0+ bytes

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       2
# Rating    2
# dtype: int64

# %%
df.replace('Blank',np.nan)
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# Replace the missing value in the Age column with mean value
df.replace(np.nan,df.mean())
# Out:
# C:\Users\HRISHIKESH\AppData\Local\Temp\ipykernel_14404\1918107110.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.replace(np.nan,df.mean())
#       Name   Age  Rating
# 0      Tom  25.0   4.230
# 1    James  26.0   3.240
# 2    Ricky  25.2   3.980
# 3    Messi  23.0   4.074
# 4  Ronaldo  25.2   4.600
# 5   Neymar  29.0   4.074
# 6     Jack  23.0   4.320

# %%
# Bracket Notaion
df['Age'].mean()
# Out:
# 25.2

# %%
df.Age.mean()
# Out:
# 25.2

# %%
df['Rating'].mean()
# Out:
# 4.074

# %%
df.Rating.mean()
# Out:
# 4.074

# %% [markdown]
# ## Drop Functions

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# Drop the "Age" column
# whenever you want t o delete a column always mention "axis = 1"
# axis = 0 for Rows
# axis = 1 for Columns
df.drop(['Age'], axis=1)
# Out:
#       Name  Rating
# 0      Tom    4.23
# 1    James    3.24
# 2    Ricky    3.98
# 3    Messi     NaN
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
# Deleting multiple columns
df.drop(['Age','Rating'],axis=1)
# Out:
#       Name
# 0      Tom
# 1    James
# 2    Ricky
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# Alternate way to solve the above column is:
# for single column 
df.drop(columns='Age')
# Out:
#       Name  Rating
# 0      Tom    4.23
# 1    James    3.24
# 2    Ricky    3.98
# 3    Messi     NaN
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
df.drop(columns='Age',axis=1)
# Out:
#       Name  Rating
# 0      Tom    4.23
# 1    James    3.24
# 2    Ricky    3.98
# 3    Messi     NaN
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
df.drop(columns='Age',axis=0)
# Out:
#       Name  Rating
# 0      Tom    4.23
# 1    James    3.24
# 2    Ricky    3.98
# 3    Messi     NaN
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
df.drop(index=[0,2,4,6])
# Out:
#      Name   Age  Rating
# 1   James  26.0    3.24
# 3   Messi  23.0     NaN
# 5  Neymar  29.0     NaN

# %%
df.drop(index=[0,2,4,6],axis=0)
# Out:
#             1      3       5
# Name    James  Messi  Neymar
# Age      26.0   23.0    29.0
# Rating   3.24    NaN     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).T
# Out:
#             1      3       5
# Name    James  Messi  Neymar
# Age      26.0   23.0    29.0
# Rating   3.24    NaN     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).sort_index()
# Out:
#      Name   Age  Rating
# 1   James  26.0    3.24
# 3   Messi  23.0     NaN
# 5  Neymar  29.0     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).sort_index(ascending=False)
# Out:
#      Name   Age  Rating
# 5  Neymar  29.0     NaN
# 3   Messi  23.0     NaN
# 1   James  26.0    3.24

# %%
df.drop(index=[0,2,4,6],axis=0).sort_values('Age',ascending=False)
# Out:
#      Name   Age  Rating
# 5  Neymar  29.0     NaN
# 1   James  26.0    3.24
# 3   Messi  23.0     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).sort_values('Age')
# Out:
#      Name   Age  Rating
# 3   Messi  23.0     NaN
# 1   James  26.0    3.24
# 5  Neymar  29.0     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).sort_values(['Rating','Age'],ascending=False)
# Out:
#      Name   Age  Rating
# 1   James  26.0    3.24
# 5  Neymar  29.0     NaN
# 3   Messi  23.0     NaN

# %%
df.drop(index=[0,2,4,6],axis=0).sort_values(['Rating','Age']
                                            ,ascending=False).loc[:,['Rating','Age']]
# Out:
#    Rating   Age
# 1    3.24  26.0
# 5     NaN  29.0
# 3     NaN  23.0

# %%
df.drop(index=[0,2,4,6],axis=0).sort_values(['Rating','Age']
                                            ,ascending=False).iloc[:,[1,2]]
# Out:
#     Age  Rating
# 1  26.0    3.24
# 5  29.0     NaN
# 3  23.0     NaN

# %%
# for multiple column is:
df.drop(columns=['Age','Rating'])
# Out:
#       Name
# 0      Tom
# 1    James
# 2    Ricky
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %% [markdown]
# ## lets try to drop the Rows using Indexing

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# here in the list we are passing the index value 
# dont count it as in the form of Rows and Columns 
df.drop([2,0])
# to delete it permanently will use inplace = True
# 0th and 2nd index position rows got deleted
# Out:
#       Name   Age  Rating
# 1    James  26.0    3.24
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# now lete delete rows which has index value of 1,3,4,6
df.drop([1,3,4,6])
# As you can see it has deleted the rows which i passed in the list
# Out:
#      Name   Age  Rating
# 0     Tom  25.0    4.23
# 2   Ricky   NaN    3.98
# 5  Neymar  29.0     NaN

# %%
# alternate way 
df.drop(index=[1,3,5])
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60
# 6     Jack  23.0    4.32

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.drop(index=1,columns='Age')
# Out:
#       Name  Rating
# 0      Tom    4.23
# 2    Ricky    3.98
# 3    Messi     NaN
# 4  Ronaldo    4.60
# 5   Neymar     NaN
# 6     Jack    4.32

# %%
df.drop(index=[1,3,5,6],columns='Age')
# Out:
#       Name  Rating
# 0      Tom    4.23
# 2    Ricky    3.98
# 4  Ronaldo    4.60

# %%
df
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.drop(index=[1,3,5,6],columns=['Age','Rating'])
# Out:
#       Name
# 0      Tom
# 2    Ricky
# 4  Ronaldo

# %%
df.drop(index=1)
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
# As we can see like query is giving us the Output,
# but it doesnt make any sense it delete the whole columns
df.drop(index=[1,3,4],columns=['Age','Name'])
# Out:
#    Rating
# 0    4.23
# 2    3.98
# 5     NaN
# 6    4.32

# %%
df.drop(columns=['Age','Rating'])
# Out:
#       Name
# 0      Tom
# 1    James
# 2    Ricky
# 3    Messi
# 4  Ronaldo
# 5   Neymar
# 6     Jack

# %%
# Let's sort the Values
df.sort_values(by = ['Age'])
# It has Sorted the Age values in the Ascending Order
# Out:
#       Name   Age  Rating
# 3    Messi  23.0     NaN
# 6     Jack  23.0    4.32
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 5   Neymar  29.0     NaN
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60

# %%
df.sort_values(by=['Age','Rating'])[['Age']]
# Out:
#     Age
# 6  23.0
# 3  23.0
# 0  25.0
# 1  26.0
# 5  29.0
# 2   NaN
# 4   NaN

# %%
df.sort_values(by=['Age','Rating']).iloc[:,1]
# Out:
# 6    23.0
# 3    23.0
# 0    25.0
# 1    26.0
# 5    29.0
# 2     NaN
# 4     NaN
# Name: Age, dtype: float64

# %%
df.sort_values(by=['Age','Rating']).iloc[:,[1]]
# Out:
#     Age
# 6  23.0
# 3  23.0
# 0  25.0
# 1  26.0
# 5  29.0
# 2   NaN
# 4   NaN

# %%
df.sort_values(by=['Age','Rating']).loc[:,['Age']]
# Out:
#     Age
# 6  23.0
# 3  23.0
# 0  25.0
# 1  26.0
# 5  29.0
# 2   NaN
# 4   NaN

# %%
df.sort_values(by=['Age','Rating']).loc[:,['Age','Rating']]
# Out:
#     Age  Rating
# 6  23.0    4.32
# 3  23.0     NaN
# 0  25.0    4.23
# 1  26.0    3.24
# 5  29.0     NaN
# 2   NaN    3.98
# 4   NaN    4.60

# %%
df.sort_values(by=['Age','Rating'])[['Name','Age']]
# Out:
#       Name   Age
# 6     Jack  23.0
# 3    Messi  23.0
# 0      Tom  25.0
# 1    James  26.0
# 5   Neymar  29.0
# 2    Ricky   NaN
# 4  Ronaldo   NaN

# %%
df.sort_values(by=['Age','Rating'],ascending=False)[['Name','Age']]
# Out:
#       Name   Age
# 5   Neymar  29.0
# 1    James  26.0
# 0      Tom  25.0
# 6     Jack  23.0
# 3    Messi  23.0
# 4  Ronaldo   NaN
# 2    Ricky   NaN

# %%
# alternate way
df.Age.sort_values()
# Out:
# 3    23.0
# 6    23.0
# 0    25.0
# 1    26.0
# 5    29.0
# 2     NaN
# 4     NaN
# Name: Age, dtype: float64

# %%
df['Age'].sort_values()
# Out:
# 3    23.0
# 6    23.0
# 0    25.0
# 1    26.0
# 5    29.0
# 2     NaN
# 4     NaN
# Name: Age, dtype: float64

# %%
df.sort_values('Age')
# Out:
#       Name   Age  Rating
# 3    Messi  23.0     NaN
# 6     Jack  23.0    4.32
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 5   Neymar  29.0     NaN
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60

# %%
df['Age'].sort_values()
# Out:
# 3    23.0
# 6    23.0
# 0    25.0
# 1    26.0
# 5    29.0
# 2     NaN
# 4     NaN
# Name: Age, dtype: float64

# %%
df.sort_values('Age')
# Out:
#       Name   Age  Rating
# 3    Messi  23.0     NaN
# 6     Jack  23.0    4.32
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 5   Neymar  29.0     NaN
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60

# %%
df['Age'].sort_values(ascending=False)
# Out:
# 5    29.0
# 1    26.0
# 0    25.0
# 3    23.0
# 6    23.0
# 2     NaN
# 4     NaN
# Name: Age, dtype: float64

# %%
df.sort_values(by=["Age"],ascending=False)
# Out:
#       Name   Age  Rating
# 5   Neymar  29.0     NaN
# 1    James  26.0    3.24
# 0      Tom  25.0    4.23
# 3    Messi  23.0     NaN
# 6     Jack  23.0    4.32
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60

# %%
df.sort_values(by=["Age"],ascending=False)
# Out:
#       Name   Age  Rating
# 5   Neymar  29.0     NaN
# 1    James  26.0    3.24
# 0      Tom  25.0    4.23
# 3    Messi  23.0     NaN
# 6     Jack  23.0    4.32
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60

# %%
df.sort_values(by=['Age','Rating'])
# bydefault it will give the first preference to the Age column
# Out:
#       Name   Age  Rating
# 6     Jack  23.0    4.32
# 3    Messi  23.0     NaN
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 5   Neymar  29.0     NaN
# 2    Ricky   NaN    3.98
# 4  Ronaldo   NaN    4.60

# %%
df.sort_values(by=['Age','Rating']).iloc[:,::-1]
# Out:
#    Rating   Age     Name
# 6    4.32  23.0     Jack
# 3     NaN  23.0    Messi
# 0    4.23  25.0      Tom
# 1    3.24  26.0    James
# 5     NaN  29.0   Neymar
# 2    3.98   NaN    Ricky
# 4    4.60   NaN  Ronaldo

# %%
df.sort_values(by=['Rating','Age'],ascending=False)
# Out:
#       Name   Age  Rating
# 4  Ronaldo   NaN    4.60
# 6     Jack  23.0    4.32
# 0      Tom  25.0    4.23
# 2    Ricky   NaN    3.98
# 1    James  26.0    3.24
# 5   Neymar  29.0     NaN
# 3    Messi  23.0     NaN

# %%
df.sort_index()
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.sort_index(axis=1)
# Out:
#     Age     Name  Rating
# 0  25.0      Tom    4.23
# 1  26.0    James    3.24
# 2   NaN    Ricky    3.98
# 3  23.0    Messi     NaN
# 4   NaN  Ronaldo    4.60
# 5  29.0   Neymar     NaN
# 6  23.0     Jack    4.32

# %%
df.sort_index(axis=0)
# Out:
#       Name   Age  Rating
# 0      Tom  25.0    4.23
# 1    James  26.0    3.24
# 2    Ricky   NaN    3.98
# 3    Messi  23.0     NaN
# 4  Ronaldo   NaN    4.60
# 5   Neymar  29.0     NaN
# 6     Jack  23.0    4.32

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#       Name   Age  Rating
# 6     Jack  23.0    4.32
# 5   Neymar  29.0     NaN
# 4  Ronaldo   NaN    4.60
# 3    Messi  23.0     NaN
# 2    Ricky   NaN    3.98
# 1    James  26.0    3.24
# 0      Tom  25.0    4.23

# %%
df.sort_index(axis=1)
# it has sorted the column in ascending order (alphabetic way)
# Out:
#     Age     Name  Rating
# 0  25.0      Tom    4.23
# 1  26.0    James    3.24
# 2   NaN    Ricky    3.98
# 3  23.0    Messi     NaN
# 4   NaN  Ronaldo    4.60
# 5  29.0   Neymar     NaN
# 6  23.0     Jack    4.32

# %%
df.sort_index(axis=1,ascending=False)
# it has sorted the column in decending order (alphabetic way)
# Out:
#    Rating     Name   Age
# 0    4.23      Tom  25.0
# 1    3.24    James  26.0
# 2    3.98    Ricky   NaN
# 3     NaN    Messi  23.0
# 4    4.60  Ronaldo   NaN
# 5     NaN   Neymar  29.0
# 6    4.32     Jack  23.0

# %%
df.sort_index(axis=1).iloc[:,::-1]
# Out:
#    Rating     Name   Age
# 0    4.23      Tom  25.0
# 1    3.24    James  26.0
# 2    3.98    Ricky   NaN
# 3     NaN    Messi  23.0
# 4    4.60  Ronaldo   NaN
# 5     NaN   Neymar  29.0
# 6    4.32     Jack  23.0

# %%
# let see how clipboard() works 
# let a copy a tabular form dataset 
# after copying to do below following task 
df = pd.read_clipboard()
df
# Out:
#     Year                 Winner                    Runner Up         Venue  \
# 0   2022         Gujarat Titans             Rajasthan Royals     Ahmedabad
# 1   2021    Chennai Super Kings        Kolkata Knight Riders         Dubai
# 2   2020         Mumbai Indians               Delhi Capitals         Dubai
# 3   2019         Mumbai Indians          Chennai Super Kings     Hyderabad
# 4   2018    Chennai Super Kings          Sunrisers Hyderabad        Mumbai
# 5   2017         Mumbai Indians      Rising Pune Supergiants     Hyderabad
# 6   2016    Sunrisers Hyderabad  Royal Challengers Bangalore     Bangalore
# 7   2015         Mumbai Indians          Chennai Super Kings       Kolkata
# 8   2014  Kolkata Knight Riders              Kings XI Punjab     Bangalore
# 9   2013         Mumbai Indians          Chennai Super Kings       Kolkata
# 10  2012  Kolkata Knight Riders          Chennai Super Kings       Chennai
# 11  2011    Chennai Super Kings  Royal Challengers Bangalore       Chennai
# 12  2010    Chennai Super Kings               Mumbai Indians        Mumbai
# 13  2009        Deccan Chargers  Royal Challengers Bangalore  Johhanesburg
# 14  2008       Rajasthan Royals          Chennai Super Kings        Mumbai
#
#     Number of teams Player of the Match
# 0                10                  --
# 1                 8      Faf du Plessis
# 2                 8         Trent Boult
# 3                 8      Jasprit Bumrah
# 4                 8        Shane Watson
# 5                 8       Krunal Pandya
# 6                 8         Ben Cutting
# 7                 8        Rohit Sharma
# 8                 8       Manish Pandey
# 9                 9      Kieron Pollard
# 10                9     Manvinder Bisla
# 11               10        Murali Vijay
# 12                8        Suresh Raina
# 13                8         Anil Kumble
# 14                8        Yusuf Pathan

# %%
df['Player of the Match']=df['Player of the Match'].replace('--','xyz')
df
# Out:
#     Year                 Winner                    Runner Up         Venue  \
# 0   2022         Gujarat Titans             Rajasthan Royals     Ahmedabad
# 1   2021    Chennai Super Kings        Kolkata Knight Riders         Dubai
# 2   2020         Mumbai Indians               Delhi Capitals         Dubai
# 3   2019         Mumbai Indians          Chennai Super Kings     Hyderabad
# 4   2018    Chennai Super Kings          Sunrisers Hyderabad        Mumbai
# 5   2017         Mumbai Indians      Rising Pune Supergiants     Hyderabad
# 6   2016    Sunrisers Hyderabad  Royal Challengers Bangalore     Bangalore
# 7   2015         Mumbai Indians          Chennai Super Kings       Kolkata
# 8   2014  Kolkata Knight Riders              Kings XI Punjab     Bangalore
# 9   2013         Mumbai Indians          Chennai Super Kings       Kolkata
# 10  2012  Kolkata Knight Riders          Chennai Super Kings       Chennai
# 11  2011    Chennai Super Kings  Royal Challengers Bangalore       Chennai
# 12  2010    Chennai Super Kings               Mumbai Indians        Mumbai
# 13  2009        Deccan Chargers  Royal Challengers Bangalore  Johhanesburg
# 14  2008       Rajasthan Royals          Chennai Super Kings        Mumbai
#
#     Number of teams Player of the Match
# 0                10                 xyz
# 1                 8      Faf du Plessis
# 2                 8         Trent Boult
# 3                 8      Jasprit Bumrah
# 4                 8        Shane Watson
# 5                 8       Krunal Pandya
# 6                 8         Ben Cutting
# 7                 8        Rohit Sharma
# 8                 8       Manish Pandey
# 9                 9      Kieron Pollard
# 10                9     Manvinder Bisla
# 11               10        Murali Vijay
# 12                8        Suresh Raina
# 13                8         Anil Kumble
# 14                8        Yusuf Pathan

# %%
df['Player of the Match']=df['Player of the Match'].str.replace('--','xyz')

# %%
df
# Out:
#     Year                 Winner                    Runner Up         Venue  \
# 0   2022         Gujarat Titans             Rajasthan Royals     Ahmedabad
# 1   2021    Chennai Super Kings        Kolkata Knight Riders         Dubai
# 2   2020         Mumbai Indians               Delhi Capitals         Dubai
# 3   2019         Mumbai Indians          Chennai Super Kings     Hyderabad
# 4   2018    Chennai Super Kings          Sunrisers Hyderabad        Mumbai
# 5   2017         Mumbai Indians      Rising Pune Supergiants     Hyderabad
# 6   2016    Sunrisers Hyderabad  Royal Challengers Bangalore     Bangalore
# 7   2015         Mumbai Indians          Chennai Super Kings       Kolkata
# 8   2014  Kolkata Knight Riders              Kings XI Punjab     Bangalore
# 9   2013         Mumbai Indians          Chennai Super Kings       Kolkata
# 10  2012  Kolkata Knight Riders          Chennai Super Kings       Chennai
# 11  2011    Chennai Super Kings  Royal Challengers Bangalore       Chennai
# 12  2010    Chennai Super Kings               Mumbai Indians        Mumbai
# 13  2009        Deccan Chargers  Royal Challengers Bangalore  Johhanesburg
# 14  2008       Rajasthan Royals          Chennai Super Kings        Mumbai
#
#     Number of teams Player of the Match
# 0                10                 xyz
# 1                 8      Faf du Plessis
# 2                 8         Trent Boult
# 3                 8      Jasprit Bumrah
# 4                 8        Shane Watson
# 5                 8       Krunal Pandya
# 6                 8         Ben Cutting
# 7                 8        Rohit Sharma
# 8                 8       Manish Pandey
# 9                 9      Kieron Pollard
# 10                9     Manvinder Bisla
# 11               10        Murali Vijay
# 12                8        Suresh Raina
# 13                8         Anil Kumble
# 14                8        Yusuf Pathan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 15 non-null     int64
#  1   Winner               15 non-null     object
#  2   Runner Up            15 non-null     object
#  3   Venue                15 non-null     object
#  4   Number of teams      15 non-null     int64
#  5   Player of the Match  15 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 840.0+ bytes
