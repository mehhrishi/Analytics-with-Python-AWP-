# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('movies.csv')
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df.shape
# Out:
# (979, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
df.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
df.describe()
# By default it will only give you Numerical dtype column
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
df.describe(include=object)
# Out:
#           title content_rating  genre  \
# count       979            976    979
# unique      975             12     16
# top     Dracula              R  Drama
# freq          2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
df.describe(include='object')
# It will only retrieve the object Column
# Out:
#           title content_rating  genre  \
# count       979            976    979
# unique      975             12     16
# top     Dracula              R  Drama
# freq          2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
# include = all will get you both categorical as well as Numercical
df.describe(include='all')
# Out:
#         star_rating    title content_rating  genre    duration  \
# count    979.000000      979            976    979  979.000000
# unique          NaN      975             12     16         NaN
# top             NaN  Dracula              R  Drama         NaN
# freq            NaN        2            460    278         NaN
# mean       7.889785      NaN            NaN    NaN  120.979571
# std        0.336069      NaN            NaN    NaN   26.218010
# min        7.400000      NaN            NaN    NaN   64.000000
# 25%        7.600000      NaN            NaN    NaN  102.000000
# 50%        7.800000      NaN            NaN    NaN  117.000000
# 75%        8.100000      NaN            NaN    NaN  134.000000
# max        9.300000      NaN            NaN    NaN  242.000000
#
#                                               actors_list
# count                                                 979
# unique                                                969
# ...

# %%
# fetching a column using "dot notation"
df.title
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
df.loc[:,'title']
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
df.loc[:,["title"]]
# Out:
#                                                title
# 0                           The Shawshank Redemption
# 1                                      The Godfather
# 2                             The Godfather: Part II
# 3                                    The Dark Knight
# 4                                       Pulp Fiction
# ..                                               ...
# 974                                          Tootsie
# 975                      Back to the Future Part III
# 976  Master and Commander: The Far Side of the World
# 977                                      Poltergeist
# 978                                      Wall Street
#
# [979 rows x 1 columns]

# %%
df.loc[:,['title','duration']]
# Out:
#                                                title  duration
# 0                           The Shawshank Redemption       142
# 1                                      The Godfather       175
# 2                             The Godfather: Part II       200
# 3                                    The Dark Knight       152
# 4                                       Pulp Fiction       154
# ..                                               ...       ...
# 974                                          Tootsie       116
# 975                      Back to the Future Part III       118
# 976  Master and Commander: The Far Side of the World       138
# 977                                      Poltergeist       114
# 978                                      Wall Street       126
#
# [979 rows x 2 columns]

# %%
# it will sort the title column in Ascending order,
# with the help of Alphabetic way 
df.title.sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
df.sort_values(by='title')['title']
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
df.sort_values(by = 'title').loc[:,'title']
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
df.title.sort_values().loc[:,['title']]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 df.title.sort_values().loc[:,['title']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1143, in _LocIndexer._getitem_tuple(self, tup)
#    1140     return self._getitem_lowerdim(tup)
#    1142 # no multi-index, so validate all of the indexers
# -> 1143 tup = self._validate_tuple_indexer(tup)
#    1145 # ugly hack for GH #836
#    1146 if self._multi_take_opportunity(tup):
#
# ...

# %%
df.sort_values(by='title')[['title']]
# Out:
#                      title
# 542   (500) Days of Summer
# 5             12 Angry Men
# 201       12 Years a Slave
# 698              127 Hours
# 110  2001: A Space Odyssey
# ..                     ...
# 955       Zero Dark Thirty
# 677                 Zodiac
# 615             Zombieland
# 526                   Zulu
# 864                  [Rec]
#
# [979 rows x 1 columns]

# %%
df.sort_values(by = 'title').loc[:,['title']]
# Out:
#                      title
# 542   (500) Days of Summer
# 5             12 Angry Men
# 201       12 Years a Slave
# 698              127 Hours
# 110  2001: A Space Odyssey
# ..                     ...
# 955       Zero Dark Thirty
# 677                 Zodiac
# 615             Zombieland
# 526                   Zulu
# 864                  [Rec]
#
# [979 rows x 1 columns]

# %%
df.sort_values(by='title')[['title','duration']]
# Out:
#                      title  duration
# 542   (500) Days of Summer        95
# 5             12 Angry Men        96
# 201       12 Years a Slave       134
# 698              127 Hours        94
# 110  2001: A Space Odyssey       160
# ..                     ...       ...
# 955       Zero Dark Thirty       157
# 677                 Zodiac       157
# 615             Zombieland        88
# 526                   Zulu       138
# 864                  [Rec]        78
#
# [979 rows x 2 columns]

# %%
df.sort_values(['title']).loc[:,['title','duration']]
# Out:
#                      title  duration
# 542   (500) Days of Summer        95
# 5             12 Angry Men        96
# 201       12 Years a Slave       134
# 698              127 Hours        94
# 110  2001: A Space Odyssey       160
# ..                     ...       ...
# 955       Zero Dark Thirty       157
# 677                 Zodiac       157
# 615             Zombieland        88
# 526                   Zulu       138
# 864                  [Rec]        78
#
# [979 rows x 2 columns]

# %%
# # it will sort the title column in Ascending order,
# with the help of Alphabetic way 
# and will get you the first five rows
df.title.sort_values().head()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
# Name: title, dtype: object

# %%
df.sort_values(['title']).iloc[:,1:2]
# Out:
#                      title
# 542   (500) Days of Summer
# 5             12 Angry Men
# 201       12 Years a Slave
# 698              127 Hours
# 110  2001: A Space Odyssey
# ..                     ...
# 955       Zero Dark Thirty
# 677                 Zodiac
# 615             Zombieland
# 526                   Zulu
# 864                  [Rec]
#
# [979 rows x 1 columns]

# %%
# if you want to get the column in the descending order 
df.title.sort_values(ascending=False)
# Out:
# 864                    [Rec]
# 526                     Zulu
# 615               Zombieland
# 677                   Zodiac
# 955         Zero Dark Thirty
#                ...
# 110    2001: A Space Odyssey
# 698                127 Hours
# 201         12 Years a Slave
# 5               12 Angry Men
# 542     (500) Days of Summer
# Name: title, Length: 979, dtype: object

# %%
df.sort_values('title',ascending=False)
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 864          7.5                  [Rec]              R     Horror        78
# 526          7.8                   Zulu        UNRATED      Drama       138
# 615          7.7             Zombieland              R     Comedy        88
# 677          7.7                 Zodiac              R      Crime       157
# 955          7.4       Zero Dark Thirty              R      Drama       157
# ..           ...                    ...            ...        ...       ...
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# 698          7.6              127 Hours              R  Adventure        94
# 201          8.1       12 Years a Slave              R  Biography       134
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
#
#                                            actors_list
# ...

# %%
df.sort_values('title',ascending=False).loc[:,['title']]
# Out:
#                      title
# 864                  [Rec]
# 526                   Zulu
# 615             Zombieland
# 677                 Zodiac
# 955       Zero Dark Thirty
# ..                     ...
# 110  2001: A Space Odyssey
# 698              127 Hours
# 201       12 Years a Slave
# 5             12 Angry Men
# 542   (500) Days of Summer
#
# [979 rows x 1 columns]

# %%
# if you want to get the column in the descending order 
df.title.sort_values(ascending=False).head()
# Out:
# 864               [Rec]
# 526                Zulu
# 615          Zombieland
# 677              Zodiac
# 955    Zero Dark Thirty
# Name: title, dtype: object

# %%
df['title'].sort_values(ascending=False)
# Out:
# 864                    [Rec]
# 526                     Zulu
# 615               Zombieland
# 677                   Zodiac
# 955         Zero Dark Thirty
#                ...
# 110    2001: A Space Odyssey
# 698                127 Hours
# 201         12 Years a Slave
# 5               12 Angry Men
# 542     (500) Days of Summer
# Name: title, Length: 979, dtype: object

# %%
df.title.sort_values(ascending=False).head()
# Out:
# 864               [Rec]
# 526                Zulu
# 615          Zombieland
# 677              Zodiac
# 955    Zero Dark Thirty
# Name: title, dtype: object

# %%
df.sort_values("title",ascending=False).head().loc[:,'title']
# Out:
# 864               [Rec]
# 526                Zulu
# 615          Zombieland
# 677              Zodiac
# 955    Zero Dark Thirty
# Name: title, dtype: object

# %%
df.sort_values("title",ascending=False).head().loc[:,['title']]
# Out:
#                 title
# 864             [Rec]
# 526              Zulu
# 615        Zombieland
# 677            Zodiac
# 955  Zero Dark Thirty

# %%
df.sort_values("title",ascending=False).loc[:,'title'].head()
# Out:
# 864               [Rec]
# 526                Zulu
# 615          Zombieland
# 677              Zodiac
# 955    Zero Dark Thirty
# Name: title, dtype: object

# %%
df.sort_values("title",ascending=False).loc[:,['title']].head()
# Out:
#                 title
# 864             [Rec]
# 526              Zulu
# 615        Zombieland
# 677            Zodiac
# 955  Zero Dark Thirty

# %%
df.sort_values('title')
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# ..           ...                    ...            ...        ...       ...
# 955          7.4       Zero Dark Thirty              R      Drama       157
# 677          7.7                 Zodiac              R      Crime       157
# 615          7.7             Zombieland              R     Comedy        88
# 526          7.8                   Zulu        UNRATED      Drama       138
# 864          7.5                  [Rec]              R     Horror        78
#
#                                            actors_list
# ...

# %%
df.sort_values('title').head()
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
#
#                                            actors_list
# 542  [u'Zooey Deschanel', u'Joseph Gordon-Levitt', ...
# 5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 201  [u'Chiwetel Ejiofor', u'Michael Kenneth Willia...
# 698  [u'James Franco', u'Amber Tamblyn', u'Kate Mara']
# 110  [u'Keir Dullea', u'Gary Lockwood', u'William S...

# %%
# if we want to sort two columns in ascending order 
df.sort_values(['star_rating','duration'])
# so it will give the first preference to the first parameter 
# which is "star_rating" column.
# Out:
#      star_rating                                          title  \
# 938          7.4                            Alice in Wonderland
# 948          7.4                                     Frances Ha
# 966          7.4                             The Simpsons Movie
# 947          7.4                                     Eraserhead
# 971          7.4                             Death at a Funeral
# ..           ...                                            ...
# 7            8.9  The Lord of the Rings: The Return of the King
# 3            9.0                                The Dark Knight
# 2            9.1                         The Godfather: Part II
# 1            9.2                                  The Godfather
# 0            9.3                       The Shawshank Redemption
#
#     content_rating      genre  duration  \
# 938              G  Animation        75
# 948              R     Comedy        86
# 966          PG-13  Animation        87
# ...

# %%
df.sort_values(['star_rating','duration']).iloc[:,[0,2]]
# Out:
#      star_rating content_rating
# 938          7.4              G
# 948          7.4              R
# 966          7.4          PG-13
# 947          7.4        UNRATED
# 971          7.4              R
# ..           ...            ...
# 7            8.9          PG-13
# 3            9.0          PG-13
# 2            9.1              R
# 1            9.2              R
# 0            9.3              R
#
# [979 rows x 2 columns]

# %%
# if we want to sort two columns in decending order 
df.sort_values(['duration','star_rating'],ascending=False).head().iloc[:,[4,0]]
# so it will give the first preference to the first parameter 
# which is "duration" column.
# Out:
#      duration  star_rating
# 476       242          7.8
# 157       238          8.2
# 78        229          8.4
# 142       224          8.3
# 445       220          7.9

# %% [markdown]
# # Filtering

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# get duration which is graeter than equal to 200
df.duration>=200
# it will return the boolean value for the column called "duration"
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: duration, Length: 979, dtype: bool

# %%
df['duration']>=200
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: duration, Length: 979, dtype: bool

# %%
df[(df.duration>=200)]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
# if you only need duration column then 
df[(df.duration>=200)][['title', 'duration']]
# Out:
#                                              title  duration
# 2                           The Godfather: Part II       200
# 7    The Lord of the Rings: The Return of the King       201
# 17                                   Seven Samurai       207
# 78                     Once Upon a Time in America       229
# 85                              Lawrence of Arabia       216
# 142              Lagaan: Once Upon a Time in India       224
# 157                             Gone with the Wind       238
# 204                                        Ben-Hur       212
# 445                           The Ten Commandments       220
# 476                                         Hamlet       242
# 630                                      Malcolm X       202
# 767                It's a Mad, Mad, Mad, Mad World       205

# %%
df[df.duration>=200][['title']]
# Out:
#                                              title
# 2                           The Godfather: Part II
# 7    The Lord of the Rings: The Return of the King
# 17                                   Seven Samurai
# 78                     Once Upon a Time in America
# 85                              Lawrence of Arabia
# 142              Lagaan: Once Upon a Time in India
# 157                             Gone with the Wind
# 204                                        Ben-Hur
# 445                           The Ten Commandments
# 476                                         Hamlet
# 630                                      Malcolm X
# 767                It's a Mad, Mad, Mad, Mad World

# %%
df[df.duration>=200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
df[(df.duration>=200)].sort_values(by='duration')[['title','duration']]
# Out:
#                                              title  duration
# 2                           The Godfather: Part II       200
# 7    The Lord of the Rings: The Return of the King       201
# 630                                      Malcolm X       202
# 767                It's a Mad, Mad, Mad, Mad World       205
# 17                                   Seven Samurai       207
# 204                                        Ben-Hur       212
# 85                              Lawrence of Arabia       216
# 445                           The Ten Commandments       220
# 142              Lagaan: Once Upon a Time in India       224
# 78                     Once Upon a Time in America       229
# 157                             Gone with the Wind       238
# 476                                         Hamlet       242

# %%
df[(df.duration>=200)].sort_values(by='duration',ascending=False)[['title','duration']]
# Out:
#                                              title  duration
# 476                                         Hamlet       242
# 157                             Gone with the Wind       238
# 78                     Once Upon a Time in America       229
# 142              Lagaan: Once Upon a Time in India       224
# 445                           The Ten Commandments       220
# 85                              Lawrence of Arabia       216
# 204                                        Ben-Hur       212
# 17                                   Seven Samurai       207
# 767                It's a Mad, Mad, Mad, Mad World       205
# 630                                      Malcolm X       202
# 7    The Lord of the Rings: The Return of the King       201
# 2                           The Godfather: Part II       200

# %%
df[df.duration==200]
# Out:
#    star_rating                   title content_rating  genre  duration  \
# 2          9.1  The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
df[df.duration==200].iloc[:,::-1]
# Out:
#                                          actors_list  duration  genre  \
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...       200  Crime
#
#   content_rating                   title  star_rating
# 2              R  The Godfather: Part II          9.1

# %%
# lets caheck the genre of the movie duration which >=200
df[(df.duration>=200)][['title','genre','duration']]
# Out:
#                                              title      genre  duration
# 2                           The Godfather: Part II      Crime       200
# 7    The Lord of the Rings: The Return of the King  Adventure       201
# 17                                   Seven Samurai      Drama       207
# 78                     Once Upon a Time in America      Crime       229
# 85                              Lawrence of Arabia  Adventure       216
# 142              Lagaan: Once Upon a Time in India  Adventure       224
# 157                             Gone with the Wind      Drama       238
# 204                                        Ben-Hur  Adventure       212
# 445                           The Ten Commandments  Adventure       220
# 476                                         Hamlet      Drama       242
# 630                                      Malcolm X  Biography       202
# 767                It's a Mad, Mad, Mad, Mad World     Action       205

# %%
df[df.duration>=200][['title']]
# Out:
#                                              title
# 2                           The Godfather: Part II
# 7    The Lord of the Rings: The Return of the King
# 17                                   Seven Samurai
# 78                     Once Upon a Time in America
# 85                              Lawrence of Arabia
# 142              Lagaan: Once Upon a Time in India
# 157                             Gone with the Wind
# 204                                        Ben-Hur
# 445                           The Ten Commandments
# 476                                         Hamlet
# 630                                      Malcolm X
# 767                It's a Mad, Mad, Mad, Mad World

# %%
# lets caheck the genre of the movie duration which >=200
df[(df.duration>=200)][['title','genre','duration']]
# Out:
#                                              title      genre  duration
# 2                           The Godfather: Part II      Crime       200
# 7    The Lord of the Rings: The Return of the King  Adventure       201
# 17                                   Seven Samurai      Drama       207
# 78                     Once Upon a Time in America      Crime       229
# 85                              Lawrence of Arabia  Adventure       216
# 142              Lagaan: Once Upon a Time in India  Adventure       224
# 157                             Gone with the Wind      Drama       238
# 204                                        Ben-Hur  Adventure       212
# 445                           The Ten Commandments  Adventure       220
# 476                                         Hamlet      Drama       242
# 630                                      Malcolm X  Biography       202
# 767                It's a Mad, Mad, Mad, Mad World     Action       205

# %%
df[(df.duration>=200)].loc[:,['title','genre','duration']]
# Out:
#                                              title      genre  duration
# 2                           The Godfather: Part II      Crime       200
# 7    The Lord of the Rings: The Return of the King  Adventure       201
# 17                                   Seven Samurai      Drama       207
# 78                     Once Upon a Time in America      Crime       229
# 85                              Lawrence of Arabia  Adventure       216
# 142              Lagaan: Once Upon a Time in India  Adventure       224
# 157                             Gone with the Wind      Drama       238
# 204                                        Ben-Hur  Adventure       212
# 445                           The Ten Commandments  Adventure       220
# 476                                         Hamlet      Drama       242
# 630                                      Malcolm X  Biography       202
# 767                It's a Mad, Mad, Mad, Mad World     Action       205

# %%
df[(df.duration>=200)].iloc[:,[1,3,4]]
# Out:
#                                              title      genre  duration
# 2                           The Godfather: Part II      Crime       200
# 7    The Lord of the Rings: The Return of the King  Adventure       201
# 17                                   Seven Samurai      Drama       207
# 78                     Once Upon a Time in America      Crime       229
# 85                              Lawrence of Arabia  Adventure       216
# 142              Lagaan: Once Upon a Time in India  Adventure       224
# 157                             Gone with the Wind      Drama       238
# 204                                        Ben-Hur  Adventure       212
# 445                           The Ten Commandments  Adventure       220
# 476                                         Hamlet      Drama       242
# 630                                      Malcolm X  Biography       202
# 767                It's a Mad, Mad, Mad, Mad World     Action       205

# %%
df[(df.duration>=200)].iloc[:,1::2]
# Out:
#                                              title      genre  \
# 2                           The Godfather: Part II      Crime
# 7    The Lord of the Rings: The Return of the King  Adventure
# 17                                   Seven Samurai      Drama
# 78                     Once Upon a Time in America      Crime
# 85                              Lawrence of Arabia  Adventure
# 142              Lagaan: Once Upon a Time in India  Adventure
# 157                             Gone with the Wind      Drama
# 204                                        Ben-Hur  Adventure
# 445                           The Ten Commandments  Adventure
# 476                                         Hamlet      Drama
# 630                                      Malcolm X  Biography
# 767                It's a Mad, Mad, Mad, Mad World     Action
#
#                                            actors_list
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# ...

# %%
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# fetching two columns
df[df.duration>=200][['genre','title']]
# Out:
#          genre                                          title
# 2        Crime                         The Godfather: Part II
# 7    Adventure  The Lord of the Rings: The Return of the King
# 17       Drama                                  Seven Samurai
# 78       Crime                    Once Upon a Time in America
# 85   Adventure                             Lawrence of Arabia
# 142  Adventure              Lagaan: Once Upon a Time in India
# 157      Drama                             Gone with the Wind
# 204  Adventure                                        Ben-Hur
# 445  Adventure                           The Ten Commandments
# 476      Drama                                         Hamlet
# 630  Biography                                      Malcolm X
# 767     Action                It's a Mad, Mad, Mad, Mad World

# %%
# fetching more than two column or multiple colummns
df[df.duration>=200][['title','genre','duration']]
# Out:
#                                              title      genre  duration
# 2                           The Godfather: Part II      Crime       200
# 7    The Lord of the Rings: The Return of the King  Adventure       201
# 17                                   Seven Samurai      Drama       207
# 78                     Once Upon a Time in America      Crime       229
# 85                              Lawrence of Arabia  Adventure       216
# 142              Lagaan: Once Upon a Time in India  Adventure       224
# 157                             Gone with the Wind      Drama       238
# 204                                        Ben-Hur  Adventure       212
# 445                           The Ten Commandments  Adventure       220
# 476                                         Hamlet      Drama       242
# 630                                      Malcolm X  Biography       202
# 767                It's a Mad, Mad, Mad, Mad World     Action       205

# %% [markdown]
# ## Using Logical Operator

# %%
# you need duration >= 200 and genre == "crime"
(df.duration>=200) & (df.genre=='Crime')
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Length: 979, dtype: bool

# %%
df[(df.duration>=200) & (df.genre=='Crime')]
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
df[(df.duration>=200) & (df.genre=='Crime')][['title','duration','genre']]
# Out:
#                           title  duration  genre
# 2        The Godfather: Part II       200  Crime
# 78  Once Upon a Time in America       229  Crime

# %%
# alternate way with "loc"
df[(df['duration']>=200) & (df['genre']=='Crime')].loc[:,['title',
                                                         'duration',
                                                         'genre']]
# Out:
#                           title  duration  genre
# 2        The Godfather: Part II       200  Crime
# 78  Once Upon a Time in America       229  Crime

# %%
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# alternate way with "iloc"
df[(df.duration>=200) & (df.genre=="Crime")].iloc[:,[1,3,4]]
# Out:
#                           title  genre  duration
# 2        The Godfather: Part II  Crime       200
# 78  Once Upon a Time in America  Crime       229

# %%
# alternate way with "iloc"
df[(df.duration>=200) & (df.genre=="Crime")].iloc[:,[1,3,4]].head(1)
# Out:
#                     title  genre  duration
# 2  The Godfather: Part II  Crime       200

# %%
df[(df.duration>=200) & (df.genre=="Crime")].iloc[:,::].head()
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
df[(df.duration>=200) & (df.genre=='Crime')].sort_values('title').iloc[:,[1,3,4]]
# Out:
#                           title  genre  duration
# 78  Once Upon a Time in America  Crime       229
# 2        The Godfather: Part II  Crime       200

# %%
df[(df.duration>=200) & (df.genre=='Crime')].sort_values(by=['duration']).iloc[:,[1,3,4]]
# Out:
#                           title  genre  duration
# 2        The Godfather: Part II  Crime       200
# 78  Once Upon a Time in America  Crime       229

# %%
df[(df.duration>=200) & (df.genre=='Crime')].sort_values(by=['title'],ascending=False).iloc[:,[1,3,4]]
# Out:
#                           title  genre  duration
# 2        The Godfather: Part II  Crime       200
# 78  Once Upon a Time in America  Crime       229

# %%
# fetching two columns
df[df.duration>=200][['genre','title']]
# Out:
#          genre                                          title
# 2        Crime                         The Godfather: Part II
# 7    Adventure  The Lord of the Rings: The Return of the King
# 17       Drama                                  Seven Samurai
# 78       Crime                    Once Upon a Time in America
# 85   Adventure                             Lawrence of Arabia
# 142  Adventure              Lagaan: Once Upon a Time in India
# 157      Drama                             Gone with the Wind
# 204  Adventure                                        Ben-Hur
# 445  Adventure                           The Ten Commandments
# 476      Drama                                         Hamlet
# 630  Biography                                      Malcolm X
# 767     Action                It's a Mad, Mad, Mad, Mad World

# %%
# fetching more than two column or multiple colummns
df[df.duration>=200][['title','genre','duration']]
# Out:
#                                              title      genre  duration
# 2                           The Godfather: Part II      Crime       200
# 7    The Lord of the Rings: The Return of the King  Adventure       201
# 17                                   Seven Samurai      Drama       207
# 78                     Once Upon a Time in America      Crime       229
# 85                              Lawrence of Arabia  Adventure       216
# 142              Lagaan: Once Upon a Time in India  Adventure       224
# 157                             Gone with the Wind      Drama       238
# 204                                        Ben-Hur  Adventure       212
# 445                           The Ten Commandments  Adventure       220
# 476                                         Hamlet      Drama       242
# 630                                      Malcolm X  Biography       202
# 767                It's a Mad, Mad, Mad, Mad World     Action       205

# %%
# Using Logical Operators
(df.duration>=200) & (df.genre=='Crime')
# here will get boolean value
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Length: 979, dtype: bool

# %%
df[(df.duration>=200) & (df.genre=="Crime")]
# it will give you all column depending upobn the condidtion you have put there
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
# lets try to get only two Column 
df[(df.duration>=200) & (df.genre=="Action")][['title','genre']]
# Out:
#                                title   genre
# 767  It's a Mad, Mad, Mad, Mad World  Action

# %%
# lets get the whole column
df[(df.duration>=200) & (df.genre=='Crime')]
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
# lets get the whole column
df[(df.duration>=200) & (df.genre=='Crime')].describe(include='all')
# Out:
#         star_rating                   title content_rating  genre    duration  \
# count      2.000000                       2              2      2    2.000000
# unique          NaN                       2              1      1         NaN
# top             NaN  The Godfather: Part II              R  Crime         NaN
# freq            NaN                       1              2      2         NaN
# mean       8.750000                     NaN            NaN    NaN  214.500000
# std        0.494975                     NaN            NaN    NaN   20.506097
# min        8.400000                     NaN            NaN    NaN  200.000000
# 25%        8.575000                     NaN            NaN    NaN  207.250000
# 50%        8.750000                     NaN            NaN    NaN  214.500000
# 75%        8.925000                     NaN            NaN    NaN  221.750000
# max        9.100000                     NaN            NaN    NaN  229.000000
#
# ...

# %% [markdown]
# ## OR operator "|"

# %%
df[(df.duration>=200) | (df.genre=='Crime')]
# Out:
#      star_rating                                          title  \
# 0            9.3                       The Shawshank Redemption
# 1            9.2                                  The Godfather
# 2            9.1                         The Godfather: Part II
# 4            8.9                                   Pulp Fiction
# 7            8.9  The Lord of the Rings: The Return of the King
# ..           ...                                            ...
# 927          7.5                                          Brick
# 931          7.4                                   Mean Streets
# 950          7.4                                          Bound
# 969          7.4                            Law Abiding Citizen
# 978          7.4                                    Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[(df.duration>=200) | (df.genre=='Crime') | (df.genre=='Adventure')]
# Out:
#      star_rating                                          title  \
# 0            9.3                       The Shawshank Redemption
# 1            9.2                                  The Godfather
# 2            9.1                         The Godfather: Part II
# 4            8.9                                   Pulp Fiction
# 7            8.9  The Lord of the Rings: The Return of the King
# ..           ...                                            ...
# 950          7.4                                          Bound
# 953          7.4                          The NeverEnding Story
# 969          7.4                            Law Abiding Citizen
# 975          7.4                    Back to the Future Part III
# 978          7.4                                    Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[(df.duration>=200) | (df.genre=='Crime') | (df.genre=='Adventure')].sort_values(by='duration',ascending=False)
# Out:
#      star_rating                              title content_rating      genre  \
# 476          7.8                             Hamlet          PG-13      Drama
# 157          8.2                 Gone with the Wind              G      Drama
# 78           8.4        Once Upon a Time in America              R      Crime
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# ..           ...                                ...            ...        ...
# 225          8.1                             3-Iron              R      Crime
# 98           8.4                           Rashomon        UNRATED      Crime
# 272          8.1                        The Killing       APPROVED      Crime
# 297          8.0                               Rope             PG      Crime
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
#
# ...

# %%
# if you need the particular column
df[(df.duration>=200) | (df.genre=='Crime') | (df.genre=='Adventure')][['title','genre','duration']]
# Out:
#                                              title      genre  duration
# 0                         The Shawshank Redemption      Crime       142
# 1                                    The Godfather      Crime       175
# 2                           The Godfather: Part II      Crime       200
# 4                                     Pulp Fiction      Crime       154
# 7    The Lord of the Rings: The Return of the King  Adventure       201
# ..                                             ...        ...       ...
# 950                                          Bound      Crime       108
# 953                          The NeverEnding Story  Adventure       102
# 969                            Law Abiding Citizen      Crime       109
# 975                    Back to the Future Part III  Adventure       118
# 978                                    Wall Street      Crime       126
#
# [204 rows x 3 columns]

# %%
df[(df.duration>=200) | (df.genre=="Action")].loc[:,['title','duration','genre']]
# Out:
#                                                title  duration      genre
# 2                             The Godfather: Part II       200      Crime
# 3                                    The Dark Knight       152     Action
# 7      The Lord of the Rings: The Return of the King       201  Adventure
# 11                                         Inception       148     Action
# 12    Star Wars: Episode V - The Empire Strikes Back       124     Action
# ..                                               ...       ...        ...
# 918                                   Running Scared       122     Action
# 954                                            X-Men       104     Action
# 963                                  La Femme Nikita       118     Action
# 967                                         The Rock       136     Action
# 976  Master and Commander: The Far Side of the World       138     Action
#
# [147 rows x 3 columns]

# %%
df[(df.genre=="Crime") | (df.genre=="Adventure") | (df.genre=="Action")]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 967          7.4                                         The Rock
# 969          7.4                              Law Abiding Citizen
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[(df.genre=="Crime") | (df.genre=="Adventure") | (df.genre=="Action")].count()
# Out:
# star_rating       335
# title             335
# content_rating    333
# genre             335
# duration          335
# actors_list       335
# dtype: int64

# %%
df.count()
# Out:
# star_rating       979
# title             979
# content_rating    976
# genre             979
# duration          979
# actors_list       979
# dtype: int64

# %%
df[(df.genre=="Crime") | (df.genre=="Adventure") | (df.genre=="Action")].head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df[(df.genre=="Crime") | (df.genre=="Adventure") | (df.genre=="Action")].tail()
# Out:
#      star_rating                                            title  \
# 967          7.4                                         The Rock
# 969          7.4                              Law Abiding Citizen
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 967              R     Action       136
# 969              R      Crime       109
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 978              R      Crime       126
#
#                                            actors_list
# 967   [u'Sean Connery', u'Nicolas Cage', u'Ed Harris']
# 969  [u'Gerard Butler', u'Jamie Foxx', u'Leslie Bibb']
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# ...

# %%
df[(df.genre=="Crime") | (df.genre=="Adventure") | (df.genre=="Action")].sort_index()
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 967          7.4                                         The Rock
# 969          7.4                              Law Abiding Citizen
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[(df.genre=="Crime") | (df.genre=="Adventure") | (df.genre=="Action")].sort_index(ascending=False)
# Out:
#      star_rating                                            title  \
# 978          7.4                                      Wall Street
# 976          7.4  Master and Commander: The Far Side of the World
# 975          7.4                      Back to the Future Part III
# 969          7.4                              Law Abiding Citizen
# 967          7.4                                         The Rock
# ..           ...                                              ...
# 4            8.9                                     Pulp Fiction
# 3            9.0                                  The Dark Knight
# 2            9.1                           The Godfather: Part II
# 1            9.2                                    The Godfather
# 0            9.3                         The Shawshank Redemption
#
#     content_rating      genre  duration  \
# 978              R      Crime       126
# 976          PG-13     Action       138
# 975             PG  Adventure       118
# ...

# %%
df[(df.genre=="Crime") | (df.genre=="Adventure") | (df.genre=="Action")].sort_values('star_rating')
# Out:
#      star_rating                                      title content_rating  \
# 978          7.4                                Wall Street              R
# 931          7.4                               Mean Streets              R
# 932          7.4  Harry Potter and the Order of the Phoenix          PG-13
# 935          7.4                                  Excalibur              R
# 936          7.4                                  True Grit            NaN
# ..           ...                                        ...            ...
# 4            8.9                               Pulp Fiction              R
# 3            9.0                            The Dark Knight          PG-13
# 2            9.1                     The Godfather: Part II              R
# 1            9.2                              The Godfather              R
# 0            9.3                   The Shawshank Redemption              R
#
# ...

# %%
df[(df.genre=="Crime") | (df.genre=="Adventure") | (df.genre=="Action")]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 967          7.4                                         The Rock
# 969          7.4                              Law Abiding Citizen
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %% [markdown]
# ## Methods

# %%
df = pd.read_table('chiporders.tsv')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# ### Lets perform some String Functions on DataFrame(df)

# %%
df.item_name.str.upper()
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
#                         ...
# 4617                            STEAK BURRITO
# 4618                            STEAK BURRITO
# 4619                       CHICKEN SALAD BOWL
# 4620                       CHICKEN SALAD BOWL
# 4621                       CHICKEN SALAD BOWL
# Name: item_name, Length: 4622, dtype: object

# %%
df['item_name'].str.upper()
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
#                         ...
# 4617                            STEAK BURRITO
# 4618                            STEAK BURRITO
# 4619                       CHICKEN SALAD BOWL
# 4620                       CHICKEN SALAD BOWL
# 4621                       CHICKEN SALAD BOWL
# Name: item_name, Length: 4622, dtype: object

# %%
df[df['item_name'].str.upper()][['item_name']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [125], line 1
# ----> 1 df[df['item_name'].str.upper()][['item_name']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
# ...

# %%
# df['item_name'].str.upper().loc[:,['item_name']]
df.loc[:,['item_name']].str.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [124], line 2
#       1 # df['item_name'].str.upper().loc[:,['item_name']]
# ----> 2 df.loc[:,['item_name']].str.upper()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
df.item_name.str.upper().sort_values()
# Out:
# 3389    6 PACK SOFT DRINK
# 341     6 PACK SOFT DRINK
# 1849    6 PACK SOFT DRINK
# 1860    6 PACK SOFT DRINK
# 2713    6 PACK SOFT DRINK
#               ...
# 2384    VEGGIE SOFT TACOS
# 781     VEGGIE SOFT TACOS
# 2851    VEGGIE SOFT TACOS
# 1699    VEGGIE SOFT TACOS
# 1395    VEGGIE SOFT TACOS
# Name: item_name, Length: 4622, dtype: object

# %%
df.item_name.str.lower()
# Out:
# 0                chips and fresh tomato salsa
# 1                                        izze
# 2                            nantucket nectar
# 3       chips and tomatillo-green chili salsa
# 4                                chicken bowl
#                         ...
# 4617                            steak burrito
# 4618                            steak burrito
# 4619                       chicken salad bowl
# 4620                       chicken salad bowl
# 4621                       chicken salad bowl
# Name: item_name, Length: 4622, dtype: object

# %%
df.item_name.str.capitalize()
# Out:
# 0                Chips and fresh tomato salsa
# 1                                        Izze
# 2                            Nantucket nectar
# 3       Chips and tomatillo-green chili salsa
# 4                                Chicken bowl
#                         ...
# 4617                            Steak burrito
# 4618                            Steak burrito
# 4619                       Chicken salad bowl
# 4620                       Chicken salad bowl
# 4621                       Chicken salad bowl
# Name: item_name, Length: 4622, dtype: object

# %%
df.item_name.str.title()
# Out:
# 0                Chips And Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips And Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
# As you can see there are space between the item name 
# instaed odf space we can replace it with "_" underscore 
df.item_name.str.replace(" ","_")
# Out:
# 0                Chips_and_Fresh_Tomato_Salsa
# 1                                        Izze
# 2                            Nantucket_Nectar
# 3       Chips_and_Tomatillo-Green_Chili_Salsa
# 4                                Chicken_Bowl
#                         ...
# 4617                            Steak_Burrito
# 4618                            Steak_Burrito
# 4619                       Chicken_Salad_Bowl
# 4620                       Chicken_Salad_Bowl
# 4621                       Chicken_Salad_Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
df[df.item_name.str.contains('Chicken')][['item_name']]
# Out:
#                  item_name
# 4             Chicken Bowl
# 5             Chicken Bowl
# 11    Chicken Crispy Tacos
# 12      Chicken Soft Tacos
# 13            Chicken Bowl
# ...                    ...
# 4604          Chicken Bowl
# 4615    Chicken Soft Tacos
# 4619    Chicken Salad Bowl
# 4620    Chicken Salad Bowl
# 4621    Chicken Salad Bowl
#
# [1560 rows x 1 columns]

# %%
df[df.item_name.str.contains('Chicken')].loc[:,'item_name']
# Out:
# 4               Chicken Bowl
# 5               Chicken Bowl
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
# 13              Chicken Bowl
#                 ...
# 4604            Chicken Bowl
# 4615      Chicken Soft Tacos
# 4619      Chicken Salad Bowl
# 4620      Chicken Salad Bowl
# 4621      Chicken Salad Bowl
# Name: item_name, Length: 1560, dtype: object

# %%
df[df.item_name.str.contains('Chicken')].loc[:,['item_name']]
# Out:
#                  item_name
# 4             Chicken Bowl
# 5             Chicken Bowl
# 11    Chicken Crispy Tacos
# 12      Chicken Soft Tacos
# 13            Chicken Bowl
# ...                    ...
# 4604          Chicken Bowl
# 4615    Chicken Soft Tacos
# 4619    Chicken Salad Bowl
# 4620    Chicken Salad Bowl
# 4621    Chicken Salad Bowl
#
# [1560 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df[df.item_name.str.contains('Chicken')].iloc[:,2]
# Out:
# 4               Chicken Bowl
# 5               Chicken Bowl
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
# 13              Chicken Bowl
#                 ...
# 4604            Chicken Bowl
# 4615      Chicken Soft Tacos
# 4619      Chicken Salad Bowl
# 4620      Chicken Salad Bowl
# 4621      Chicken Salad Bowl
# Name: item_name, Length: 1560, dtype: object

# %%
df[df.item_name.str.contains('Chicken')].iloc[:,[2]]
# Out:
#                  item_name
# 4             Chicken Bowl
# 5             Chicken Bowl
# 11    Chicken Crispy Tacos
# 12      Chicken Soft Tacos
# 13            Chicken Bowl
# ...                    ...
# 4604          Chicken Bowl
# 4615    Chicken Soft Tacos
# 4619    Chicken Salad Bowl
# 4620    Chicken Salad Bowl
# 4621    Chicken Salad Bowl
#
# [1560 rows x 1 columns]

# %%
df[df.item_name.str.contains('Chicken')].iloc[:,2:3]
# Out:
#                  item_name
# 4             Chicken Bowl
# 5             Chicken Bowl
# 11    Chicken Crispy Tacos
# 12      Chicken Soft Tacos
# 13            Chicken Bowl
# ...                    ...
# 4604          Chicken Bowl
# 4615    Chicken Soft Tacos
# 4619    Chicken Salad Bowl
# 4620    Chicken Salad Bowl
# 4621    Chicken Salad Bowl
#
# [1560 rows x 1 columns]

# %%
df.groupby('item_name').str.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [137], line 1
# ----> 1 df.groupby('item_name').str.upper()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'str'
