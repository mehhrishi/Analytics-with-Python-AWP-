# %% [markdown]
# ## Reading Tabular DataFile in Pandas

# %%
import numpy as np 
import pandas as pd

# %%
#pd.read_table(file_name,sep="\t")

#Sep = ","   Comma S Value(CSV)
#Sep = "|"   Pipe S Value(PSV)
#Sep = "\t"  Tab S Value(TSV)

# %%
df = pd.read_table('chiporders.tsv',sep='\t')
df
# the datafile is already tab spaced 
# As such we don't require to put sep="\t" as a parameter
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ## CSV

# %%
df = pd.read_csv('drinks.csv',sep=',')
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df = pd.read_csv('drinks.csv')
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
# to read the excel file you need to first install the library first
# !pip install xlrd

# %%
# !pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...

# %%
df = pd.read_excel('exbook.xlsx')
df
# Out:
#    Sr.NO                                   Books            Author  year  \
# 0      1                  The Discovery of India  Jawaharlal Nehru  1946
# 1      2  The Story of my Experiments with Truth    Mahatma Gandhi  1927
# 2      3                 Glimps of World History           J.Nehru  1934
# 3      4                       A Guide to Health    Mahatma Gandhi  1921
# 4      5                           Ignited Minds   APJ Abdul Kalam  2002
# 5      6                           Wings of Fire   APJ Abdul Kalam  1999
#
#      Price  Profit
# 0   599.95    0.30
# 1   159.00    0.30
# 2   750.46    0.24
# 3   250.00    0.25
# 4   300.00    0.10
# 5  1275.25    0.10

# %%
df = pd.read_table('psd.user')
df
# As you can see the file is "pipe line separated"
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %%
df = pd.read_table('psd.user',sep='|')
df
# Out:
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# ..   ...  .. ..            ...    ...
# 937  939  26  F        student  33319
# 938  940  32  M  administrator  02215
# 939  941  20  M        student  97229
# 940  942  48  F      librarian  78209
# 941  943  22  M        student  77841
#
# [942 rows x 5 columns]
